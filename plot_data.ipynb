# %%
import deepdish as dd
import matplotlib.pyplot as plt

# %%
data = dd.io.load("laguna_del_maule_miller.h5")

# %%
iz = 20

plt.pcolormesh(data["x"], data["y"], data["model"][:, :, iz])
plt.title(f"z = {data['z'][iz]}m")
# Out:
# Text(0.5, 1.0, 'z = 387.5m')

# %%
iy = 29

plt.pcolormesh(data["x"], data["z"], data["model"][:, iy, :].T)
plt.title(f"y = {data['y'][iy]}m")
# Out:
# Text(0.5, 1.0, 'y = 6006375.0m')
